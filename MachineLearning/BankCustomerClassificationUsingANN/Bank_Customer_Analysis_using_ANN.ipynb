# %% [markdown]
# # Predicting Costumer that will leave the Bank

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time

# %%
ann_data = pd.read_csv("/content/Churn_Modelling.csv")
ann_data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
ann_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
ann_data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
ann = ann_data.copy()#DeepCopy

# %% [markdown]
# ## Visualization

# %%
# Visualizing the count of 'exited customers' in the dataset
plt.figure(figsize=(8,8))
sns.countplot(x='Exited', data=ann)
plt.xlabel('0: Customers still with the bank, 1: Customers exited the bank')
plt.ylabel('Count')
plt.title('Bank Customers Churn Visualization')
plt.show()

# %% [markdown]
# Target Variable Vs Features:

# %%
sns.set(rc = {"figure.figsize": (8, 6)})

# %%
sns.boxplot(x="Exited", y="Age", data=ann)
# Out:
# <Axes: xlabel='Exited', ylabel='Age'>

# %%
sns.violinplot(x="Exited", y="NumOfProducts", data=ann, palette="Set1")
# Out:
# <Axes: xlabel='Exited', ylabel='NumOfProducts'>

# %%
sns.boxplot(x="Geography", y="Exited", data=ann)
# Out:
# <Axes: xlabel='Geography', ylabel='Exited'>

# %% [markdown]
# ## Correlation

# %%
corr = ann.corr(numeric_only = True)
ax = sns.heatmap(corr,annot=True,cmap='RdYlGn',linewidths=0.1,annot_kws={'size':12})
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
fig=plt.gcf()
fig.set_size_inches(12,10)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
ann.drop(['RowNumber','CustomerId','Surname'], axis=1, inplace=True)
ann.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %% [markdown]
# ## Encoding Categorical Data

# %% [markdown]
# Converting categorical data into a numerical format using the get_dummies() function of the pandas library so that the data can be understood by the machine and can be inserted into the ANN Model for training and prediction.

# %%
# Converting 'Geography' and 'Gender' column
geography = pd.get_dummies(ann['Geography'], drop_first=True)
gender = pd.get_dummies(ann['Gender'], drop_first=True)

# %%
# Appending columns to original dataframe
ann = pd.concat([ann, geography, gender], axis=1)
ann.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited', 'Germany', 'Spain', 'Male'],
#       dtype='object')

# %%
ann.drop(['Geography', 'Gender'], axis=1, inplace=True)

# %% [markdown]
# ## Input and Output variable

# %%
X = ann.drop('Exited', axis=1)
y = ann['Exited']

# %% [markdown]
# ## Spliting

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## PreProcessing

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Building the Neural Network

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))

# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 200)
# Out:
# Epoch 1/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4886 - accuracy: 0.7950
# Epoch 2/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4284 - accuracy: 0.7960
# Epoch 3/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4231 - accuracy: 0.7960
# Epoch 4/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4189 - accuracy: 0.8069
# Epoch 5/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4168 - accuracy: 0.8242
# Epoch 6/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4148 - accuracy: 0.8282
# Epoch 7/200
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4139 - accuracy: 0.8284
# Epoch 8/200
# 800/800 [==============================] - 3s 4ms/step - loss: 0.4117 - accuracy: 0.8314
# Epoch 9/200
# 800/800 [==============================] - 3s 3ms/step - loss: 0.4114 - accuracy: 0.8320
# Epoch 10/200
# 800/800 [==============================] - 4s 4ms/step - loss: 0.4108 - accuracy: 0.8340
# Epoch 11/200
# 800/800 [==============================] - 3s 3ms/step - loss: 0.4098 - accuracy: 0.8329
# Epoch 12/200
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4091 - accuracy: 0.8353
# Epoch 13/200
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4085 - accuracy: 0.8341
# Epoch 14/200
# 800/800 [==============================] - 4s 5ms/step - loss: 0.4077 - accuracy: 0.8331
# Epoch 15/200
# 800/800 [==============================] - 3s 4ms/step - loss: 0.4073 - accuracy: 0.8355
# Epoch 16/200
# 800/800 [==============================] - 3s 4ms/step - loss: 0.4063 - accuracy: 0.8349
# Epoch 17/200
# 800/800 [==============================] - 3s 3ms/step - loss: 0.4062 - accuracy: 0.8354
# Epoch 18/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4061 - accuracy: 0.8347
# Epoch 19/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4054 - accuracy: 0.8339
# Epoch 20/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4050 - accuracy: 0.8361
# Epoch 21/200
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4050 - accuracy: 0.8349
# Epoch 22/200
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4045 - accuracy: 0.8359
# Epoch 23/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4046 - accuracy: 0.8342
# Epoch 24/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4039 - accuracy: 0.8346
# Epoch 25/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4039 - accuracy: 0.8356
# Epoch 26/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4037 - accuracy: 0.8342
# Epoch 27/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4032 - accuracy: 0.8351
# Epoch 28/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4033 - accuracy: 0.8353
# Epoch 29/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4029 - accuracy: 0.8342
# Epoch 30/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4028 - accuracy: 0.8330
# Epoch 31/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4027 - accuracy: 0.8354
# Epoch 32/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4026 - accuracy: 0.8355
# Epoch 33/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4023 - accuracy: 0.8350
# Epoch 34/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4021 - accuracy: 0.8340
# Epoch 35/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4019 - accuracy: 0.8340
# Epoch 36/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4019 - accuracy: 0.8349
# Epoch 37/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4018 - accuracy: 0.8363
# Epoch 38/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4012 - accuracy: 0.8339
# Epoch 39/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4013 - accuracy: 0.8361
# Epoch 40/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4016 - accuracy: 0.8335
# Epoch 41/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4013 - accuracy: 0.8342
# Epoch 42/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4012 - accuracy: 0.8338
# Epoch 43/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4009 - accuracy: 0.8338
# Epoch 44/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4010 - accuracy: 0.8339
# Epoch 45/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4011 - accuracy: 0.8363
# Epoch 46/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4008 - accuracy: 0.8364
# Epoch 47/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4006 - accuracy: 0.8354
# Epoch 48/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4009 - accuracy: 0.8350
# Epoch 49/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4004 - accuracy: 0.8344
# Epoch 50/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4009 - accuracy: 0.8344
# Epoch 51/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4002 - accuracy: 0.8361
# Epoch 52/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4005 - accuracy: 0.8339
# Epoch 53/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4003 - accuracy: 0.8346
# Epoch 54/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4003 - accuracy: 0.8350
# Epoch 55/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4006 - accuracy: 0.8346
# Epoch 56/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4003 - accuracy: 0.8350
# Epoch 57/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4002 - accuracy: 0.8346
# Epoch 58/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4000 - accuracy: 0.8346
# Epoch 59/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4002 - accuracy: 0.8351
# Epoch 60/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3998 - accuracy: 0.8346
# Epoch 61/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4002 - accuracy: 0.8335
# Epoch 62/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4000 - accuracy: 0.8357
# Epoch 63/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4004 - accuracy: 0.8346
# Epoch 64/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4005 - accuracy: 0.8356
# Epoch 65/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4000 - accuracy: 0.8336
# Epoch 66/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4004 - accuracy: 0.8346
# Epoch 67/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4002 - accuracy: 0.8355
# Epoch 68/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4000 - accuracy: 0.8341
# Epoch 69/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3999 - accuracy: 0.8349
# Epoch 70/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3997 - accuracy: 0.8353
# Epoch 71/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3998 - accuracy: 0.8356
# Epoch 72/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3995 - accuracy: 0.8356
# Epoch 73/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3997 - accuracy: 0.8353
# Epoch 74/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4002 - accuracy: 0.8347
# Epoch 75/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3999 - accuracy: 0.8344
# Epoch 76/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4001 - accuracy: 0.8341
# Epoch 77/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3998 - accuracy: 0.8340
# Epoch 78/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4002 - accuracy: 0.8346
# Epoch 79/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3997 - accuracy: 0.8342
# Epoch 80/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4002 - accuracy: 0.8338
# Epoch 81/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4000 - accuracy: 0.8351
# Epoch 82/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3996 - accuracy: 0.8349
# Epoch 83/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3999 - accuracy: 0.8342
# Epoch 84/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3995 - accuracy: 0.8342
# Epoch 85/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3995 - accuracy: 0.8353
# Epoch 86/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3991 - accuracy: 0.8353
# Epoch 87/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3999 - accuracy: 0.8349
# Epoch 88/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3996 - accuracy: 0.8346
# Epoch 89/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3997 - accuracy: 0.8338
# Epoch 90/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4000 - accuracy: 0.8326
# Epoch 91/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3996 - accuracy: 0.8345
# Epoch 92/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3998 - accuracy: 0.8354
# Epoch 93/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3993 - accuracy: 0.8355
# Epoch 94/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3996 - accuracy: 0.8354
# Epoch 95/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3997 - accuracy: 0.8359
# Epoch 96/200
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3996 - accuracy: 0.8338
# Epoch 97/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3998 - accuracy: 0.8344
# Epoch 98/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3996 - accuracy: 0.8351
# Epoch 99/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3994 - accuracy: 0.8356
# Epoch 100/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3996 - accuracy: 0.8340
# Epoch 101/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3995 - accuracy: 0.8345
# Epoch 102/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3993 - accuracy: 0.8345
# Epoch 103/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3997 - accuracy: 0.8351
# Epoch 104/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3997 - accuracy: 0.8347
# Epoch 105/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3995 - accuracy: 0.8363
# Epoch 106/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3992 - accuracy: 0.8350
# Epoch 107/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3996 - accuracy: 0.8351
# Epoch 108/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3995 - accuracy: 0.8356
# Epoch 109/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3993 - accuracy: 0.8350
# Epoch 110/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3995 - accuracy: 0.8344
# Epoch 111/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3990 - accuracy: 0.8359
# Epoch 112/200
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3995 - accuracy: 0.8344
# Epoch 113/200
# 800/800 [==============================] - 5s 6ms/step - loss: 0.3993 - accuracy: 0.8336
# Epoch 114/200
# 800/800 [==============================] - 3s 3ms/step - loss: 0.3988 - accuracy: 0.8340
# Epoch 115/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3992 - accuracy: 0.8359
# Epoch 116/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3993 - accuracy: 0.8364
# Epoch 117/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3996 - accuracy: 0.8350
# Epoch 118/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3992 - accuracy: 0.8346
# Epoch 119/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3991 - accuracy: 0.8355
# Epoch 120/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3996 - accuracy: 0.8361
# Epoch 121/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3991 - accuracy: 0.8329
# Epoch 122/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3993 - accuracy: 0.8339
# Epoch 123/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3994 - accuracy: 0.8341
# Epoch 124/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3995 - accuracy: 0.8347
# Epoch 125/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3992 - accuracy: 0.8347
# Epoch 126/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3989 - accuracy: 0.8361
# Epoch 127/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4000 - accuracy: 0.8339
# Epoch 128/200
# 800/800 [==============================] - 4s 5ms/step - loss: 0.3990 - accuracy: 0.8355
# Epoch 129/200
# 800/800 [==============================] - 3s 3ms/step - loss: 0.3989 - accuracy: 0.8339
# Epoch 130/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3987 - accuracy: 0.8347
# Epoch 131/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3995 - accuracy: 0.8354
# Epoch 132/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3993 - accuracy: 0.8344
# Epoch 133/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3989 - accuracy: 0.8347
# Epoch 134/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3990 - accuracy: 0.8332
# Epoch 135/200
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3994 - accuracy: 0.8347
# Epoch 136/200
# 800/800 [==============================] - 3s 3ms/step - loss: 0.3993 - accuracy: 0.8345
# Epoch 137/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3994 - accuracy: 0.8345
# Epoch 138/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3989 - accuracy: 0.8353
# Epoch 139/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3991 - accuracy: 0.8344
# Epoch 140/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3992 - accuracy: 0.8340
# Epoch 141/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3994 - accuracy: 0.8353
# Epoch 142/200
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3992 - accuracy: 0.8360
# Epoch 143/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3993 - accuracy: 0.8340
# Epoch 144/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3988 - accuracy: 0.8341
# Epoch 145/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3990 - accuracy: 0.8338
# Epoch 146/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3994 - accuracy: 0.8356
# Epoch 147/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3991 - accuracy: 0.8344
# Epoch 148/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3990 - accuracy: 0.8344
# Epoch 149/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3994 - accuracy: 0.8355
# Epoch 150/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3990 - accuracy: 0.8354
# Epoch 151/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3989 - accuracy: 0.8338
# Epoch 152/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3989 - accuracy: 0.8347
# Epoch 153/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3993 - accuracy: 0.8353
# Epoch 154/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3996 - accuracy: 0.8351
# Epoch 155/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3989 - accuracy: 0.8357
# Epoch 156/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3987 - accuracy: 0.8344
# Epoch 157/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3997 - accuracy: 0.8338
# Epoch 158/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3990 - accuracy: 0.8366
# Epoch 159/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3988 - accuracy: 0.8338
# Epoch 160/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3984 - accuracy: 0.8338
# Epoch 161/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3990 - accuracy: 0.8347
# Epoch 162/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3990 - accuracy: 0.8342
# Epoch 163/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3991 - accuracy: 0.8356
# Epoch 164/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3994 - accuracy: 0.8365
# Epoch 165/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3983 - accuracy: 0.8350
# Epoch 166/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3990 - accuracy: 0.8354
# Epoch 167/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3991 - accuracy: 0.8351
# Epoch 168/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3990 - accuracy: 0.8342
# Epoch 169/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3994 - accuracy: 0.8342
# Epoch 170/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3990 - accuracy: 0.8351
# Epoch 171/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3991 - accuracy: 0.8345
# Epoch 172/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3991 - accuracy: 0.8345
# Epoch 173/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3991 - accuracy: 0.8341
# Epoch 174/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3991 - accuracy: 0.8353
# Epoch 175/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3988 - accuracy: 0.8344
# Epoch 176/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3991 - accuracy: 0.8349
# Epoch 177/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3992 - accuracy: 0.8345
# Epoch 178/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3990 - accuracy: 0.8349
# Epoch 179/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3987 - accuracy: 0.8351
# Epoch 180/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3990 - accuracy: 0.8351
# Epoch 181/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3990 - accuracy: 0.8355
# Epoch 182/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3992 - accuracy: 0.8330
# Epoch 183/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3985 - accuracy: 0.8350
# Epoch 184/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3990 - accuracy: 0.8356
# Epoch 185/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3989 - accuracy: 0.8341
# Epoch 186/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3988 - accuracy: 0.8347
# Epoch 187/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3991 - accuracy: 0.8363
# Epoch 188/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3986 - accuracy: 0.8340
# Epoch 189/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3992 - accuracy: 0.8344
# Epoch 190/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3988 - accuracy: 0.8356
# Epoch 191/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3989 - accuracy: 0.8347
# Epoch 192/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3993 - accuracy: 0.8334
# Epoch 193/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3995 - accuracy: 0.8354
# Epoch 194/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3985 - accuracy: 0.8350
# Epoch 195/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3993 - accuracy: 0.8344
# Epoch 196/200
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3990 - accuracy: 0.8356
# Epoch 197/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3990 - accuracy: 0.8347
# Epoch 198/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3990 - accuracy: 0.8336
# Epoch 199/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3990 - accuracy: 0.8359
# Epoch 200/200
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3989 - accuracy: 0.8356

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
y_pred
# Out:
# 63/63 [==============================] - 0s 1ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1551,   44],
#        [ 266,  139]])

# %% [markdown]
# #### As you can see there are no missclassified samples in the Confusion Matrix. Therefor, the Accuracy Score = 0.1

# %%
# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score = accuracy_score(y_pred,y_test)
print('The accuracy for ANN model is: {}%'.format(score*100))
# Out:
# The accuracy for ANN model is: 84.5%

# %%
plt.figure(figsize=(8,6))
sns.heatmap(cm, cmap='Blues', annot=True, xticklabels=['Did not Exit', 'Exit'], yticklabels=['Did not Exit', 'Exit'])
plt.xlabel('Predicted values')
plt.ylabel('Actual values')
plt.title('Confusion Matrix for ANN model')
plt.show()
